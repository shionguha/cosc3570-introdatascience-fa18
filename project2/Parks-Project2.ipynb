# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from datascience import *
# %matplotlib inline
from scipy import stats
from scipy.stats import norm

import statsmodels.api as sm 
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split

plt.style.use('classic')

# %% [markdown]
# <b> NBA 2014-2015 Shot Log Data Analysis <b>

# %%
#Zachary Parks 
#Project 2
#Data retrieved from https://www.kaggle.com/dansbecker/nba-shot-logs/home
#2014-2015 NBA season shot log data 

#loads the data into a pandas data frame 
shots = pd.read_csv('shot_logs.csv')
#Take a look at the data 
shots
# Out:
#          GAME_ID                     MATCHUP LOCATION  W  FINAL_MARGIN  \
# 0       21400899    MAR 04, 2015 - CHA @ BKN        A  W            24
# 1       21400899    MAR 04, 2015 - CHA @ BKN        A  W            24
# 2       21400899    MAR 04, 2015 - CHA @ BKN        A  W            24
# 3       21400899    MAR 04, 2015 - CHA @ BKN        A  W            24
# 4       21400899    MAR 04, 2015 - CHA @ BKN        A  W            24
# 5       21400899    MAR 04, 2015 - CHA @ BKN        A  W            24
# 6       21400899    MAR 04, 2015 - CHA @ BKN        A  W            24
# 7       21400899    MAR 04, 2015 - CHA @ BKN        A  W            24
# 8       21400899    MAR 04, 2015 - CHA @ BKN        A  W            24
# 9       21400890  MAR 03, 2015 - CHA vs. LAL        H  W             1
# 10      21400890  MAR 03, 2015 - CHA vs. LAL        H  W             1
# 11      21400890  MAR 03, 2015 - CHA vs. LAL        H  W             1
# 12      21400890  MAR 03, 2015 - CHA vs. LAL        H  W             1
# 13      21400882    MAR 01, 2015 - CHA @ ORL        A  W            15
# 14      21400859    FEB 27, 2015 - CHA @ BOS        A  L            -8
# 15      21400859    FEB 27, 2015 - CHA @ BOS        A  L            -8
# 16      21400859    FEB 27, 2015 - CHA @ BOS        A  L            -8
# 17      21400859    FEB 27, 2015 - CHA @ BOS        A  L            -8
# 18      21400859    FEB 27, 2015 - CHA @ BOS        A  L            -8
# 19      21400845    FEB 25, 2015 - CHA @ CHI        A  W            12
# 20      21400845    FEB 25, 2015 - CHA @ CHI        A  W            12
# 21      21400845    FEB 25, 2015 - CHA @ CHI        A  W            12
# 22      21400845    FEB 25, 2015 - CHA @ CHI        A  W            12
# 23      21400845    FEB 25, 2015 - CHA @ CHI        A  W            12
# 24      21400845    FEB 25, 2015 - CHA @ CHI        A  W            12
# 25      21400845    FEB 25, 2015 - CHA @ CHI        A  W            12
# 26      21400845    FEB 25, 2015 - CHA @ CHI        A  W            12
# 27      21400827    FEB 22, 2015 - CHA @ DAL        A  L           -11
# 28      21400827    FEB 22, 2015 - CHA @ DAL        A  L           -11
# 29      21400827    FEB 22, 2015 - CHA @ DAL        A  L           -11
# ...          ...                         ...      ... ..           ...
# 128039  21400075  NOV 07, 2014 - BKN vs. NYK        H  W            11
# 128040  21400075  NOV 07, 2014 - BKN vs. NYK        H  W            11
# 128041  21400075  NOV 07, 2014 - BKN vs. NYK        H  W            11
# 128042  21400075  NOV 07, 2014 - BKN vs. NYK        H  W            11
# 128043  21400060  NOV 05, 2014 - BKN vs. MIN        H  L            -7
# 128044  21400060  NOV 05, 2014 - BKN vs. MIN        H  L            -7
# 128045  21400060  NOV 05, 2014 - BKN vs. MIN        H  L            -7
# 128046  21400060  NOV 05, 2014 - BKN vs. MIN        H  L            -7
# 128047  21400060  NOV 05, 2014 - BKN vs. MIN        H  L            -7
# 128048  21400060  NOV 05, 2014 - BKN vs. MIN        H  L            -7
# 128049  21400060  NOV 05, 2014 - BKN vs. MIN        H  L            -7
# 128050  21400060  NOV 05, 2014 - BKN vs. MIN        H  L            -7
# 128051  21400044  NOV 03, 2014 - BKN vs. OKC        H  W            31
# 128052  21400044  NOV 03, 2014 - BKN vs. OKC        H  W            31
# 128053  21400044  NOV 03, 2014 - BKN vs. OKC        H  W            31
# 128054  21400044  NOV 03, 2014 - BKN vs. OKC        H  W            31
# 128055  21400044  NOV 03, 2014 - BKN vs. OKC        H  W            31
# 128056  21400033    NOV 01, 2014 - BKN @ DET        A  W            12
# 128057  21400033    NOV 01, 2014 - BKN @ DET        A  W            12
# 128058  21400033    NOV 01, 2014 - BKN @ DET        A  W            12
# 128059  21400033    NOV 01, 2014 - BKN @ DET        A  W            12
# 128060  21400006    OCT 29, 2014 - BKN @ BOS        A  L           -16
# 128061  21400006    OCT 29, 2014 - BKN @ BOS        A  L           -16
# 128062  21400006    OCT 29, 2014 - BKN @ BOS        A  L           -16
# 128063  21400006    OCT 29, 2014 - BKN @ BOS        A  L           -16
# 128064  21400006    OCT 29, 2014 - BKN @ BOS        A  L           -16
# 128065  21400006    OCT 29, 2014 - BKN @ BOS        A  L           -16
# 128066  21400006    OCT 29, 2014 - BKN @ BOS        A  L           -16
# 128067  21400006    OCT 29, 2014 - BKN @ BOS        A  L           -16
# 128068  21400006    OCT 29, 2014 - BKN @ BOS        A  L           -16
#
#         SHOT_NUMBER  PERIOD GAME_CLOCK  SHOT_CLOCK  DRIBBLES    ...     \
# 0                 1       1       1:09        10.8         2    ...
# 1                 2       1       0:14         3.4         0    ...
# 2                 3       1       0:00         NaN         3    ...
# 3                 4       2      11:47        10.3         2    ...
# 4                 5       2      10:34        10.9         2    ...
# 5                 6       2       8:15         9.1         2    ...
# 6                 7       4      10:15        14.5        11    ...
# 7                 8       4       8:00         3.4         3    ...
# 8                 9       4       5:14        12.4         0    ...
# 9                 1       2      11:32        17.4         0    ...
# 10                2       2       6:30        16.0         8    ...
# 11                3       4      11:32        12.1        14    ...
# 12                4       4       8:55         4.3         2    ...
# 13                1       4       9:10         4.4         0    ...
# 14                1       1       0:48         6.8         0    ...
# 15                2       2      10:38         6.4         3    ...
# 16                3       2       8:27        17.6         6    ...
# 17                4       4      10:55         8.7         1    ...
# 18                5       4      10:29        20.8         0    ...
# 19                1       1       3:35        17.5         2    ...
# 20                2       1       0:33        19.5         5    ...
# 21                3       2       8:50         6.0         6    ...
# 22                4       2       8:24        15.7         0    ...
# 23                5       2       5:32        11.2        16    ...
# 24                6       2       0:04         NaN         0    ...
# 25                7       4      10:13        17.1         7    ...
# 26                8       4       5:34        15.4         1    ...
# 27                1       1       2:25        12.3         0    ...
# 28                2       2       9:08        18.2         7    ...
# 29                3       2       8:53        11.9         1    ...
# ...             ...     ...        ...         ...       ...    ...
# 128039            2       2       9:05         7.9         6    ...
# 128040            3       4      11:13         8.8         0    ...
# 128041            4       4       4:23        10.3         3    ...
# 128042            5       4       0:06         4.0        20    ...
# 128043            1       2      11:48        12.1        16    ...
# 128044            2       2      10:05         8.4         3    ...
# 128045            3       2       9:34         9.0         0    ...
# 128046            4       3       4:01        19.3         2    ...
# 128047            5       3       3:05         7.3         6    ...
# 128048            6       4      11:01         9.0         0    ...
# 128049            7       4       7:27        11.0         2    ...
# 128050            8       4       6:41        22.7         1    ...
# 128051            2       1       0:16         NaN         3    ...
# 128052            3       2      10:29        19.3         2    ...
# 128053            4       3       6:15         3.2         5    ...
# 128054            5       3       3:17         4.1         2    ...
# 128055            6       4      11:22        13.8         0    ...
# 128056            1       1       1:50         7.1         2    ...
# 128057            2       2      10:02         7.3         0    ...
# 128058            3       4      10:57        14.3         2    ...
# 128059            4       4       8:34        19.8         0    ...
# 128060            1       1       1:59        11.4        16    ...
# 128061            2       2      10:10        19.0         0    ...
# 128062            3       2       7:46         7.0         1    ...
# 128063            4       2       5:05        15.3         2    ...
# 128064            5       3       1:52        18.3         5    ...
# 128065            6       4      11:28        19.8         4    ...
# 128066            7       4      11:10        23.0         2    ...
# 128067            8       4       2:37         9.1         4    ...
# 128068            9       4       0:12         NaN         5    ...
#
#         SHOT_DIST  PTS_TYPE  SHOT_RESULT    CLOSEST_DEFENDER  \
# 0             7.7         2         made      Anderson, Alan
# 1            28.2         3       missed   Bogdanovic, Bojan
# 2            10.1         2       missed   Bogdanovic, Bojan
# 3            17.2         2       missed       Brown, Markel
# 4             3.7         2       missed     Young, Thaddeus
# 5            18.4         2       missed     Williams, Deron
# 6            20.7         2       missed       Jack, Jarrett
# 7             3.5         2         made      Plumlee, Mason
# 8            24.6         3       missed      Morris, Darius
# 9            22.4         3       missed    Ellington, Wayne
# 10           24.5         3       missed         Lin, Jeremy
# 11           14.6         2         made         Lin, Jeremy
# 12            5.9         2         made        Hill, Jordan
# 13           26.4         3       missed       Green, Willie
# 14           22.8         3       missed       Smart, Marcus
# 15           24.7         3         made        Young, James
# 16           25.0         3       missed      Jerebko, Jonas
# 17           25.6         3       missed        Crowder, Jae
# 18           24.2         3         made      Thomas, Isaiah
# 19           25.4         3       missed       Brooks, Aaron
# 20           19.1         2         made       Hinrich, Kirk
# 21           14.8         2         made         Gibson, Taj
# 22           25.2         3       missed       Hinrich, Kirk
# 23           22.8         3         made         Gibson, Taj
# 24           25.2         3       missed       Butler, Jimmy
# 25           24.6         3         made        Noah, Joakim
# 26           10.6         2         made       Brooks, Aaron
# 27           20.2         2       missed       Harris, Devin
# 28           24.9         3       missed    Barea, Jose Juan
# 29            8.3         2       missed    Barea, Jose Juan
# ...           ...       ...          ...                 ...
# 128039       10.7         2       missed       Larkin, Shane
# 128040        2.5         2       missed        Smith, Jason
# 128041        7.5         2         made       Larkin, Shane
# 128042        6.8         2         made        Wear, Travis
# 128043       16.2         2         made        Williams, Mo
# 128044       17.7         2       missed        Williams, Mo
# 128045        3.6         2       missed       Dieng, Gorgui
# 128046       17.0         2       missed       Martin, Kevin
# 128047       15.5         2         made        Williams, Mo
# 128048       20.2         2         made       Brewer, Corey
# 128049        9.4         2         made     Pekovic, Nikola
# 128050        2.3         2         made        Williams, Mo
# 128051        2.6         2         made  Telfair, Sebastian
# 128052       18.9         2       missed  Telfair, Sebastian
# 128053       13.7         2       missed       Adams, Steven
# 128054       11.1         2       missed  Telfair, Sebastian
# 128055        5.1         2       missed     Jackson, Reggie
# 128056       15.5         2       missed   Jennings, Brandon
# 128057       22.1         3       missed      Augustin, D.J.
# 128058       18.2         2         made      Augustin, D.J.
# 128059       22.7         3       missed      Augustin, D.J.
# 128060       12.6         2       missed        Rondo, Rajon
# 128061        7.4         2       missed      Bradley, Avery
# 128062       14.5         2         made       Smart, Marcus
# 128063        8.9         2         made    Sullinger, Jared
# 128064        8.7         2       missed       Smart, Marcus
# 128065        0.6         2         made        Turner, Evan
# 128066       16.9         2         made    Thornton, Marcus
# 128067       18.3         2       missed      Bradley, Avery
# 128068        5.1         2         made      Bradley, Avery
#
#        CLOSEST_DEFENDER_PLAYER_ID  CLOSE_DEF_DIST  FGM  PTS    player_name  \
# 0                          101187             1.3    1    2  brian roberts
# 1                          202711             6.1    0    0  brian roberts
# 2                          202711             0.9    0    0  brian roberts
# 3                          203900             3.4    0    0  brian roberts
# 4                          201152             1.1    0    0  brian roberts
# 5                          101114             2.6    0    0  brian roberts
# 6                          101127             6.1    0    0  brian roberts
# 7                          203486             2.1    1    2  brian roberts
# 8                          202721             7.3    0    0  brian roberts
# 9                          201961            19.8    0    0  brian roberts
# 10                         202391             4.7    0    0  brian roberts
# 11                         202391             1.8    1    2  brian roberts
# 12                         201941             5.4    1    2  brian roberts
# 13                           2584             4.4    0    0  brian roberts
# 14                         203935             5.3    0    0  brian roberts
# 15                         203923             5.6    1    3  brian roberts
# 16                         201973             5.4    0    0  brian roberts
# 17                         203109             5.1    0    0  brian roberts
# 18                         202738            11.1    1    3  brian roberts
# 19                         201166             3.5    0    0  brian roberts
# 20                           2550             4.0    1    2  brian roberts
# 21                         201959             5.4    1    2  brian roberts
# 22                           2550             3.7    0    0  brian roberts
# 23                         201959             5.1    1    3  brian roberts
# 24                         202710             3.6    0    0  brian roberts
# 25                         201149             6.0    1    3  brian roberts
# 26                         201166             0.7    1    2  brian roberts
# 27                           2734             3.5    0    0  brian roberts
# 28                         200826             4.5    0    0  brian roberts
# 29                         200826             3.5    0    0  brian roberts
# ...                           ...             ...  ...  ...            ...
# 128039                     203499             1.2    0    0   jarrett jack
# 128040                     201160             5.1    0    0   jarrett jack
# 128041                     203499             0.9    1    2   jarrett jack
# 128042                     204037             0.9    1    2   jarrett jack
# 128043                       2590             2.5    1    2   jarrett jack
# 128044                       2590             1.8    0    0   jarrett jack
# 128045                     203476             1.5    0    0   jarrett jack
# 128046                       2755             3.6    0    0   jarrett jack
# 128047                       2590             2.4    1    2   jarrett jack
# 128048                     201147            11.1    1    2   jarrett jack
# 128049                     201593             6.0    1    2   jarrett jack
# 128050                       2590             7.7    1    2   jarrett jack
# 128051                       2742             5.4    1    2   jarrett jack
# 128052                       2742             3.8    0    0   jarrett jack
# 128053                     203500             2.8    0    0   jarrett jack
# 128054                       2742             4.2    0    0   jarrett jack
# 128055                     202704             2.1    0    0   jarrett jack
# 128056                     201943             3.1    0    0   jarrett jack
# 128057                     201571             2.9    0    0   jarrett jack
# 128058                     201571             1.1    1    2   jarrett jack
# 128059                     201571             4.0    0    0   jarrett jack
# 128060                     200765             4.8    0    0   jarrett jack
# 128061                     202340             2.7    0    0   jarrett jack
# 128062                     203935             3.1    1    2   jarrett jack
# 128063                     203096             5.7    1    2   jarrett jack
# 128064                     203935             0.8    0    0   jarrett jack
# 128065                     202323             0.6    1    2   jarrett jack
# 128066                     201977             4.2    1    2   jarrett jack
# 128067                     202340             3.0    0    0   jarrett jack
# 128068                     202340             2.3    1    2   jarrett jack
#
#        player_id
# 0         203148
# 1         203148
# 2         203148
# 3         203148
# 4         203148
# 5         203148
# 6         203148
# 7         203148
# 8         203148
# 9         203148
# 10        203148
# 11        203148
# 12        203148
# 13        203148
# 14        203148
# 15        203148
# 16        203148
# 17        203148
# 18        203148
# 19        203148
# 20        203148
# 21        203148
# 22        203148
# 23        203148
# 24        203148
# 25        203148
# 26        203148
# 27        203148
# 28        203148
# 29        203148
# ...          ...
# 128039    101127
# 128040    101127
# 128041    101127
# 128042    101127
# 128043    101127
# 128044    101127
# 128045    101127
# 128046    101127
# 128047    101127
# 128048    101127
# 128049    101127
# 128050    101127
# 128051    101127
# 128052    101127
# 128053    101127
# 128054    101127
# 128055    101127
# 128056    101127
# 128057    101127
# 128058    101127
# 128059    101127
# 128060    101127
# 128061    101127
# 128062    101127
# 128063    101127
# 128064    101127
# 128065    101127
# 128066    101127
# 128067    101127
# 128068    101127
#
# [128069 rows x 21 columns]

# %%
#Some of the Touch_Times were negative 
#It is impossible to touch a basketball for negative seconds, so those shots were removed 
#Same with negative dribbles and shot distance
cleanShots = shots.where(shots.TOUCH_TIME >= 0).where(shots.DRIBBLES >= 0).where(shots.SHOT_DIST >= 0).dropna()

# %%
#Subsetting the data into three point shots and two point shots 

#The furthest NBA three point line is located at 23.75 feet from the basket
#So two point shots have to be from less than 24 feet 
twos = cleanShots.where(cleanShots.PTS_TYPE == 2).where(cleanShots.SHOT_DIST <= 23.75).dropna()

#The closest a three point shot can be, by rule in the NBA, is 22 feet, so SHOT_DIST >=22
threes = cleanShots.where(cleanShots.PTS_TYPE == 3).where(cleanShots.SHOT_DIST >= 22).dropna()

# %%
#Creates a data table with statistics for 4 main pieces of data in the two point shot subset
#Computes mean, 25%, median, 75%, min, and max for Dribbles, Touch Time, Defender Distance, and Shot Distance

dTwos = {'Two Pointers': ['Mean', '25%','Median', '75%', 'Min', 'Max'], 
         'Dribbles': [twos['DRIBBLES'].mean(), twos['DRIBBLES'].quantile(.25), twos['DRIBBLES'].median(),
                      twos['DRIBBLES'].quantile(.75), twos['DRIBBLES'].min(), twos['DRIBBLES'].max()],
         'Touch Time': [twos['TOUCH_TIME'].mean(), twos['TOUCH_TIME'].quantile(.25), twos['TOUCH_TIME'].median(),
                      twos['TOUCH_TIME'].quantile(.75), twos['TOUCH_TIME'].min(), twos['TOUCH_TIME'].max()],
         'Defender Distance': [twos['CLOSE_DEF_DIST'].mean(), twos['CLOSE_DEF_DIST'].quantile(.25), twos['CLOSE_DEF_DIST'].median(),
                              twos['CLOSE_DEF_DIST'].quantile(.75), twos['CLOSE_DEF_DIST'].min(), twos['CLOSE_DEF_DIST'].max()],
         'Shot Distance': [twos['SHOT_DIST'].mean(), twos['SHOT_DIST'].quantile(.25), twos['SHOT_DIST'].median(),
                      twos['SHOT_DIST'].quantile(.75), twos['SHOT_DIST'].min(), twos['SHOT_DIST'].max()]}
tableTwos = pd.DataFrame(data = dTwos)

#Formats each column to round to 2 decimal places 
tableTwos = tableTwos.style.format({'Dribbles': "{:.2f}", 'Touch Time': "{:.2f}", 'Defender Distance': "{:.2f}", 'Shot Distance': "{:.2f}"})
tableTwos
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_9b0ca05a_00c4_11e9_8ca0_98e7f4537beb" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Two Pointers</th>
#         <th class="col_heading level0 col1" >Dribbles</th>
#         <th class="col_heading level0 col2" >Touch Time</th>
#         <th class="col_heading level0 col3" >Defender Distance</th>
#         <th class="col_heading level0 col4" >Shot Distance</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_9b0ca05a_00c4_11e9_8ca0_98e7f4537beblevel0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_9b0ca05a_00c4_11e9_8ca0_98e7f4537bebrow0_col0" class="data row0 col0" >Mean</td>
#         <td id="T_9b0ca05a_00c4_11e9_8ca0_98e7f4537bebrow0_col1" class="data row0 col1" >2.35</td>
#         <td id="T_9b0ca05a_00c4_11e9_8ca0_98e7f4537bebrow0_col2" class="data row0 col2" >3.09</td>
#         <td id="T_9b0ca05a_00c4_11e9_8ca0_98e7f4537bebrow0_col3" class="data row0 col3" >3.43</td>
#         <td id="T_9b0ca05a_00c4_11e9_8ca0_98e7f4537bebrow0_col4" class="data row0 col4" >9.54</td>
#     </tr>    <tr>
#         <th id="T_9b0ca05a_00c4_11e9_8ca0_98e7f4537beblevel0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_9b0ca05a_00c4_11e9_8ca0_98e7f4537bebrow1_col0" class="data row1 col0" >25%</td>
#         <td id="T_9b0ca05a_00c4_11e9_8ca0_98e7f4537bebrow1_col1" class="data row1 col1" >0.00</td>
#         <td id="T_9b0ca05a_00c4_11e9_8ca0_98e7f4537bebrow1_col2" class="data row1 col2" >0.90</td>
#         <td id="T_9b0ca05a_00c4_11e9_8ca0_98e7f4537bebrow1_col3" class="data row1 col3" >2.00</td>
#         <td id="T_9b0ca05a_00c4_11e9_8ca0_98e7f4537bebrow1_col4" class="data row1 col4" >3.70</td>
#     </tr>    <tr>
#         <th id="T_9b0ca05a_00c4_11e9_8ca0_98e7f4537beblevel0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_9b0ca05a_00c4_11e9_8ca0_98e7f4537bebrow2_col0" class="data row2 col0" >Median</td>
#         <td id="T_9b0ca05a_00c4_11e9_8ca0_98e7f4537bebrow2_col1" class="data row2 col1" >1.00</td>
#         <td id="T_9b0ca05a_00c4_11e9_8ca0_98e7f4537bebrow2_col2" class="data row2 col2" >2.10</td>
#         <td id="T_9b0ca05a_00c4_11e9_8ca0_98e7f4537bebrow2_col3" class="data row2 col3" >3.00</td>
#         <td id="T_9b0ca05a_00c4_11e9_8ca0_98e7f4537bebrow2_col4" class="data row2 col4" >7.30</td>
#     </tr>    <tr>
#         <th id="T_9b0ca05a_00c4_11e9_8ca0_98e7f4537beblevel0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_9b0ca05a_00c4_11e9_8ca0_98e7f4537bebrow3_col0" class="data row3 col0" >75%</td>
#         <td id="T_9b0ca05a_00c4_11e9_8ca0_98e7f4537bebrow3_col1" class="data row3 col1" >3.00</td>
#         <td id="T_9b0ca05a_00c4_11e9_8ca0_98e7f4537bebrow3_col2" class="data row3 col2" >4.20</td>
#         <td id="T_9b0ca05a_00c4_11e9_8ca0_98e7f4537bebrow3_col3" class="data row3 col3" >4.40</td>
#         <td id="T_9b0ca05a_00c4_11e9_8ca0_98e7f4537bebrow3_col4" class="data row3 col4" >16.20</td>
#     </tr>    <tr>
#         <th id="T_9b0ca05a_00c4_11e9_8ca0_98e7f4537beblevel0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_9b0ca05a_00c4_11e9_8ca0_98e7f4537bebrow4_col0" class="data row4 col0" >Min</td>
#         <td id="T_9b0ca05a_00c4_11e9_8ca0_98e7f4537bebrow4_col1" class="data row4 col1" >0.00</td>
#         <td id="T_9b0ca05a_00c4_11e9_8ca0_98e7f4537bebrow4_col2" class="data row4 col2" >0.00</td>
#         <td id="T_9b0ca05a_00c4_11e9_8ca0_98e7f4537bebrow4_col3" class="data row4 col3" >0.00</td>
#         <td id="T_9b0ca05a_00c4_11e9_8ca0_98e7f4537bebrow4_col4" class="data row4 col4" >0.00</td>
#     </tr>    <tr>
#         <th id="T_9b0ca05a_00c4_11e9_8ca0_98e7f4537beblevel0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_9b0ca05a_00c4_11e9_8ca0_98e7f4537bebrow5_col0" class="data row5 col0" >Max</td>
#         <td id="T_9b0ca05a_00c4_11e9_8ca0_98e7f4537bebrow5_col1" class="data row5 col1" >32.00</td>
#         <td id="T_9b0ca05a_00c4_11e9_8ca0_98e7f4537bebrow5_col2" class="data row5 col2" >24.50</td>
#         <td id="T_9b0ca05a_00c4_11e9_8ca0_98e7f4537bebrow5_col3" class="data row5 col3" >53.20</td>
#         <td id="T_9b0ca05a_00c4_11e9_8ca0_98e7f4537bebrow5_col4" class="data row5 col4" >23.70</td>
#     </tr></tbody>
# </table>

# %%
#Creates a table identical to the table above, except for three point shots instead of two point shots

dThrees = {'Three Pointers': ['Mean', '25%','Median', '75%', 'Min', 'Max'], 
         'Dribbles': [threes['DRIBBLES'].mean(), threes['DRIBBLES'].quantile(.25), threes['DRIBBLES'].median(),
                      threes['DRIBBLES'].quantile(.75), threes['DRIBBLES'].min(), threes['DRIBBLES'].max()],
         'Touch Time': [threes['TOUCH_TIME'].mean(), threes['TOUCH_TIME'].quantile(.25), threes['TOUCH_TIME'].median(),
                      threes['TOUCH_TIME'].quantile(.75), threes['TOUCH_TIME'].min(), threes['TOUCH_TIME'].max()],
         'Defender Distance': [threes['CLOSE_DEF_DIST'].mean(), threes['CLOSE_DEF_DIST'].quantile(.25), threes['CLOSE_DEF_DIST'].median(),
                              threes['CLOSE_DEF_DIST'].quantile(.75), threes['CLOSE_DEF_DIST'].min(), threes['CLOSE_DEF_DIST'].max()],
         'Shot Distance': [threes['SHOT_DIST'].mean(), threes['SHOT_DIST'].quantile(.25), threes['SHOT_DIST'].median(),
                      threes['SHOT_DIST'].quantile(.75), threes['SHOT_DIST'].min(), threes['SHOT_DIST'].max()]}
tableThrees = pd.DataFrame(data = dThrees)
tableThrees = tableThrees.style.format({'Dribbles': "{:.2f}", 'Touch Time': "{:.2f}", 'Defender Distance': "{:.2f}", 'Shot Distance': "{:.2f}"})
tableThrees
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_9b115e9c_00c4_11e9_8773_98e7f4537beb" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Three Pointers</th>
#         <th class="col_heading level0 col1" >Dribbles</th>
#         <th class="col_heading level0 col2" >Touch Time</th>
#         <th class="col_heading level0 col3" >Defender Distance</th>
#         <th class="col_heading level0 col4" >Shot Distance</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_9b115e9c_00c4_11e9_8773_98e7f4537beblevel0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_9b115e9c_00c4_11e9_8773_98e7f4537bebrow0_col0" class="data row0 col0" >Mean</td>
#         <td id="T_9b115e9c_00c4_11e9_8773_98e7f4537bebrow0_col1" class="data row0 col1" >1.00</td>
#         <td id="T_9b115e9c_00c4_11e9_8773_98e7f4537bebrow0_col2" class="data row0 col2" >1.83</td>
#         <td id="T_9b115e9c_00c4_11e9_8773_98e7f4537bebrow0_col3" class="data row0 col3" >6.09</td>
#         <td id="T_9b115e9c_00c4_11e9_8773_98e7f4537bebrow0_col4" class="data row0 col4" >24.48</td>
#     </tr>    <tr>
#         <th id="T_9b115e9c_00c4_11e9_8773_98e7f4537beblevel0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_9b115e9c_00c4_11e9_8773_98e7f4537bebrow1_col0" class="data row1 col0" >25%</td>
#         <td id="T_9b115e9c_00c4_11e9_8773_98e7f4537bebrow1_col1" class="data row1 col1" >0.00</td>
#         <td id="T_9b115e9c_00c4_11e9_8773_98e7f4537bebrow1_col2" class="data row1 col2" >0.80</td>
#         <td id="T_9b115e9c_00c4_11e9_8773_98e7f4537bebrow1_col3" class="data row1 col3" >4.30</td>
#         <td id="T_9b115e9c_00c4_11e9_8773_98e7f4537bebrow1_col4" class="data row1 col4" >23.60</td>
#     </tr>    <tr>
#         <th id="T_9b115e9c_00c4_11e9_8773_98e7f4537beblevel0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_9b115e9c_00c4_11e9_8773_98e7f4537bebrow2_col0" class="data row2 col0" >Median</td>
#         <td id="T_9b115e9c_00c4_11e9_8773_98e7f4537bebrow2_col1" class="data row2 col1" >0.00</td>
#         <td id="T_9b115e9c_00c4_11e9_8773_98e7f4537bebrow2_col2" class="data row2 col2" >1.00</td>
#         <td id="T_9b115e9c_00c4_11e9_8773_98e7f4537bebrow2_col3" class="data row2 col3" >5.40</td>
#         <td id="T_9b115e9c_00c4_11e9_8773_98e7f4537bebrow2_col4" class="data row2 col4" >24.50</td>
#     </tr>    <tr>
#         <th id="T_9b115e9c_00c4_11e9_8773_98e7f4537beblevel0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_9b115e9c_00c4_11e9_8773_98e7f4537bebrow3_col0" class="data row3 col0" >75%</td>
#         <td id="T_9b115e9c_00c4_11e9_8773_98e7f4537bebrow3_col1" class="data row3 col1" >0.00</td>
#         <td id="T_9b115e9c_00c4_11e9_8773_98e7f4537bebrow3_col2" class="data row3 col2" >1.40</td>
#         <td id="T_9b115e9c_00c4_11e9_8773_98e7f4537bebrow3_col3" class="data row3 col3" >7.00</td>
#         <td id="T_9b115e9c_00c4_11e9_8773_98e7f4537bebrow3_col4" class="data row3 col4" >25.20</td>
#     </tr>    <tr>
#         <th id="T_9b115e9c_00c4_11e9_8773_98e7f4537beblevel0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_9b115e9c_00c4_11e9_8773_98e7f4537bebrow4_col0" class="data row4 col0" >Min</td>
#         <td id="T_9b115e9c_00c4_11e9_8773_98e7f4537bebrow4_col1" class="data row4 col1" >0.00</td>
#         <td id="T_9b115e9c_00c4_11e9_8773_98e7f4537bebrow4_col2" class="data row4 col2" >0.00</td>
#         <td id="T_9b115e9c_00c4_11e9_8773_98e7f4537bebrow4_col3" class="data row4 col3" >0.00</td>
#         <td id="T_9b115e9c_00c4_11e9_8773_98e7f4537bebrow4_col4" class="data row4 col4" >22.00</td>
#     </tr>    <tr>
#         <th id="T_9b115e9c_00c4_11e9_8773_98e7f4537beblevel0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_9b115e9c_00c4_11e9_8773_98e7f4537bebrow5_col0" class="data row5 col0" >Max</td>
#         <td id="T_9b115e9c_00c4_11e9_8773_98e7f4537bebrow5_col1" class="data row5 col1" >30.00</td>
#         <td id="T_9b115e9c_00c4_11e9_8773_98e7f4537bebrow5_col2" class="data row5 col2" >24.90</td>
#         <td id="T_9b115e9c_00c4_11e9_8773_98e7f4537bebrow5_col3" class="data row5 col3" >28.00</td>
#         <td id="T_9b115e9c_00c4_11e9_8773_98e7f4537bebrow5_col4" class="data row5 col4" >42.80</td>
#     </tr></tbody>
# </table>

# %%
#Average and median Dribbles and touch time is significantly lower for three point shots
#Average and median Defender Distance is significantly higher for three point shots

# %%
#Look at distribution of shot distance for the whole data set 


ax = sns.distplot(cleanShots['SHOT_DIST'], kde = False, norm_hist = True, bins = range(31), color='g')

#sets up style and removes top and right frames
sns.set_context("paper", font_scale=1.5)
sns.set_style('white')
sns.despine()
#label the x axis 
ax.set_xlabel('Shot Distance (ft)')

#Draws 2 vertical lines where the three point lines are located 
#Shows a spike in shot distribution beyond the three point lines 
plt.axvline(x=22, linestyle='--')
plt.axvline(x=23.75, linestyle='--')

# %%
ax = sns.distplot(cleanShots['CLOSE_DEF_DIST'], kde = False, norm_hist = True, bins = range(17), color='g')
sns.set_context("paper", font_scale=1.5)
sns.set_style('white')
sns.despine()

ax.set_xlabel('Defender Distance (ft)')
# Out:
# Text(0.5,0,'Defender Distance (ft)')

# %%
#Create a 2x2 small multiple to compare the data of two point and three point shots

#creates a 2x2 figure and 4 axes to plot graphs on 
f, ((ax1,ax2),(ax3,ax4)) = plt.subplots(2,2,figsize=(7,7),sharey=True)

#First plot in upper left, Defender Distance
plt.subplot(221)

#Removes top and top right frames from the graph
sns.despine()
#Sets the style and makes the background white 
sns.set_context("paper", font_scale=1.5)
sns.set_style('white')

#Creates a dictionary for the two subsets of data 
data = dict()
data[0]= twos
data[1] = threes
#Makes an array for the legend 
Legend = ['2pt','3pt']

#Making 2 histograms on the same axis, one for two point and one for three point shots Defender Distance 
#Frequency tapers off significantly after Distance > 15
#Want normalized histograms with no kernal density curve 

for i in range(len(Legend)):
    ax1 = sns.distplot(data[i]['CLOSE_DEF_DIST'], bins = range(15), kde=False, norm_hist = True)
#Label the independent variable, Defender Distance 
ax1.set_xlabel('Defender Distance (ft)')


#Upper Right Plot, Touch Time 
ax2 = plt.plot(sharey=True)
plt.subplot(222)
sns.despine()

sns.set_context("paper", font_scale=1.5)
sns.set_style('white')

#Same as above, except with a legend 
#Uses 1 legend in top left graph instead of 1 legend in each graph to reduce clutter 
for i in range(len(Legend)):
    ax2 = sns.distplot(data[i]['TOUCH_TIME'], bins = range(13), kde=False, label = Legend[i], norm_hist = True)

ax2.set_xlabel('Touch Time (s)')
#Removes the border from the legend 
ax2.legend(frameon=False)

#Bottom Left plot, Dribbles
ax3 = plt.plot(sharey=True)
plt.subplot(223)
sns.despine()
sns.set_context("paper", font_scale=1.5)
sns.set_style('white')


#Same setup as previous graphs 
for i in range(len(Legend)):
    ax3 = sns.distplot(data[i]['DRIBBLES'], bins = range(13), kde=False, norm_hist = True)

ax3.set_xlabel('Dribbles')


#Bottom Left plot, Shot Distance 
ax4 = plt.plot(sharey=True)
plt.subplot(224)
sns.despine()
sns.set_context("paper", font_scale=1.5)
sns.set_style('white')

#Same setup a previous graphs but with a larger range 
for i in range(len(Legend)):
    ax4 = sns.distplot(data[i]['SHOT_DIST'], bins = range(30), kde=False, norm_hist = True)

ax4.set_xlabel('Shot Distance')


#Sets the padding between the plots 
f.subplots_adjust(hspace=.5,wspace=.5)
plt.show()

# %%
#Defenders are generally closer on two point shots than three point shots
#Touch Time and the number of Dribbles is generally lower for three point shots 
#Obviously, shot distance is lower for two point shots 
#Most two point shots happen in the 0-7ft range
#Most three point shots happen in the 23-25ft range

# %%
#Now to look at the relationship between variables 

#take a sample of the data to make the scatter plots more readable 
two_sample = twos.sample(10000)
three_sample = threes.sample(10000)

#Set up a 3x2 small multiple
f, ((ax1,ax2),(ax3,ax4),(ax5,ax6)) = plt.subplots(3,2,figsize=(7,7))


#Upper Left, Defender Distance vs Touch Time - Two Point
plt.subplot(321)
sns.set_context("paper", font_scale=1.5)
sns.set_style('white')
sns.despine()

#Left column is Two Point shots, Right column is Three Point Shots 

ax1 = sns.scatterplot(data = two_sample, y = 'CLOSE_DEF_DIST', x = 'TOUCH_TIME', legend = False, alpha = 0.05)

#sets up range of axes
#the '.5' stops the graph from cutting off points on the edge of the range 
ax1.set(xlim=(0, 25.5))
ax1.set(ylim=(0, 25.5))
#Labels each axis and title
ax1.set_ylabel('Defender Dist (ft)')
ax1.set_xlabel('Touch Time (s)')
ax1.set_title("Two Point Shots")


#Upper Right, Defender Distance vs Touch Time - Three Point
#plt.subplot(322)
sns.despine()
plt.subplot(322)
ax2 = sns.scatterplot(data = three_sample, y = 'CLOSE_DEF_DIST', x = 'TOUCH_TIME', legend = False, alpha = 0.05)

ax2.set(xlim=(0, 25.5))
ax2.set(ylim=(0, 25.5))
ax2.set_ylabel('Defender Dist (ft)')
ax2.set_xlabel('Touch Time (s)')
ax2.set_title("Three Point Shots")




#Middle Left, Dribbles vs Defender Distance - Two Point
plt.subplot(323)

ax3 = sns.scatterplot(data = two_sample, x = 'DRIBBLES', y = 'CLOSE_DEF_DIST', legend = False, alpha = 0.05)
sns.despine()
ax3.set(xlim=(-.5, 25.5))
ax3.set(ylim=(0, 25.5))
ax3.set_xlabel('Dribbles')
ax3.set_ylabel('Defender Dist (ft)')


#Middle Right, Dribbles vs Defender Distance - Three Point
plt.subplot(324)

ax4 = sns.scatterplot(data = three_sample, x = 'DRIBBLES', y = 'CLOSE_DEF_DIST', legend = False, alpha = 0.05)
sns.despine()
ax4.set(xlim=(-.5, 25.5))
ax4.set(ylim=(0, 25.5))
ax4.set_xlabel('Dribbles')
ax4.set_ylabel('Defender Dist (ft)')




#Bottom Left, Shot Distance vs Defender Distance - Two Point
plt.subplot(325)

ax5 = sns.scatterplot(data = two_sample, x = 'SHOT_DIST', y = 'CLOSE_DEF_DIST', legend = False, alpha = 0.05)
sns.despine()
ax5.set(xlim=(-.5, 25.5))
ax5.set(ylim=(0, 25.5))
ax5.set_xlabel('Shot Distance(ft)')
ax5.set_ylabel('Defender Dist (ft)')


#Bottom Right, Shot Distance vs Defender Distance - Three Point
plt.subplot(326)

ax6 = sns.scatterplot(data = three_sample, x = 'SHOT_DIST', y = 'CLOSE_DEF_DIST', legend = False, alpha = 0.05)
sns.despine()
ax6.set(xlim=(21.5, 35))
ax6.set(ylim=(0, 25.5))
ax6.set_xlabel('Shot Distance(ft)')
ax6.set_ylabel('Defender Dist (ft)')

#sets padding between plots 
f.subplots_adjust(hspace=.5,wspace=.5)
plt.show()

# %%
#For two point and three point shots, as defender distance increases, touch time decreases 
#Touch time is almost always < 10 seconds if the defender is 15 or more ft away 
#For three point shots, almost no shots when defender is within 3 ft and touch time > 10 seconds
#As the amount of dribbles increases, defender distance decreases 
#The time it takes to dribble allows defenders to get closer 
#Defender distance is usually higher for three point shots than two point shots

# %%
#Target = Defender Distance
#Predictors = Shot Distance, Dribbles, and Touch Time 

#combined model of all shots
X = cleanShots[['SHOT_DIST','DRIBBLES','TOUCH_TIME',]]
Y = cleanShots['CLOSE_DEF_DIST']

#train-test split of 80/20
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state = 32)

#Ordinary Least Squares regression on the train data 
model = sm.OLS(y_train,X_train).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         CLOSE_DEF_DIST   R-squared:                       0.743
# Model:                            OLS   Adj. R-squared:                  0.743
# Method:                 Least Squares   F-statistic:                 9.444e+04
# Date:                Sat, 15 Dec 2018   Prob (F-statistic):               0.00
# Time:                        17:53:25   Log-Likelihood:            -2.2847e+05
# No. Observations:               97762   AIC:                         4.569e+05
# Df Residuals:                   97759   BIC:                         4.570e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# SHOT_DIST      0.2451      0.001    382.639      0.000       0.244       0.246
# DRIBBLES      -0.2400      0.006    -40.321      0.000      -0.252      -0.228
# TOUCH_TIME     0.3103      0.006     48.528      0.000       0.298       0.323
# ==============================================================================
# Omnibus:                    69802.079   Durbin-Watson:                   1.942
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          4033827.118
# Skew:                           2.850   Prob(JB):                         0.00
# Kurtosis:                      33.948   Cond. No.                         17.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#run predictions on the test data 
predictions = model.predict(X_test)

#graphing the predictions vs the true test data 
sns.set_context("paper", font_scale=1.5)
sns.set_style('white')
ax = sns.regplot(x = y_test, y = predictions,  scatter_kws={'alpha':0.05}, line_kws={"color": "red"})
sns.despine()
ax.set(xlim=(0, 20))
ax.set(ylim=(0, 10))
ax.set_title("Combined Model")
plt.xlabel('True Defender Dist')
plt.ylabel('Predicted Defender Dist')
# Out:
# Text(0,0.5,'Predicted Defender Dist')

# %%
#model just for two point shots
#used exact same methodology as the previous model just with the data set of just two point shots

X = twos[['SHOT_DIST','DRIBBLES','TOUCH_TIME']]
Y = twos['CLOSE_DEF_DIST']

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state = 32)


model = sm.OLS(y_train,X_train).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         CLOSE_DEF_DIST   R-squared:                       0.689
# Model:                            OLS   Adj. R-squared:                  0.689
# Method:                 Least Squares   F-statistic:                 5.321e+04
# Date:                Sat, 15 Dec 2018   Prob (F-statistic):               0.00
# Time:                        17:53:27   Log-Likelihood:            -1.6249e+05
# No. Observations:               72069   AIC:                         3.250e+05
# Df Residuals:                   72066   BIC:                         3.250e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# SHOT_DIST      0.2627      0.001    267.977      0.000       0.261       0.265
# DRIBBLES      -0.2137      0.006    -36.500      0.000      -0.225      -0.202
# TOUCH_TIME     0.2908      0.006     45.562      0.000       0.278       0.303
# ==============================================================================
# Omnibus:                    66252.089   Durbin-Watson:                   1.900
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          9592833.730
# Skew:                           3.956   Prob(JB):                         0.00
# Kurtosis:                      58.964   Cond. No.                         12.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#predictions for the two point model

predictions = model.predict(X_test)
sns.set_context("paper", font_scale=1.5)
sns.set_style('white')
ax = sns.regplot(x = y_test, y = predictions, scatter_kws={'alpha':0.05}, line_kws={"color": "red"})
sns.despine()
ax.set(xlim=(0, 20))
ax.set(ylim=(0, 10))
ax.set_title("Two Point Model")
plt.xlabel('True Defender Dist')
plt.ylabel('Predicted Defender Dist')
# Out:
# Text(0,0.5,'Predicted Defender Dist')

# %%
#model for just three point shots
#used exact same methodology as the previous model just with the data set of just three point shots

X = threes[['SHOT_DIST','DRIBBLES', 'TOUCH_TIME', ]]
Y = threes['CLOSE_DEF_DIST']

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state = 32)


model = sm.OLS(y_train,X_train).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         CLOSE_DEF_DIST   R-squared:                       0.816
# Model:                            OLS   Adj. R-squared:                  0.816
# Method:                 Least Squares   F-statistic:                 3.657e+04
# Date:                Sat, 15 Dec 2018   Prob (F-statistic):               0.00
# Time:                        17:53:29   Log-Likelihood:                -61058.
# No. Observations:               24667   AIC:                         1.221e+05
# Df Residuals:                   24664   BIC:                         1.221e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# SHOT_DIST      0.2546      0.001    195.295      0.000       0.252       0.257
# DRIBBLES      -0.1384      0.022     -6.350      0.000      -0.181      -0.096
# TOUCH_TIME    -0.0284      0.025     -1.135      0.257      -0.078       0.021
# ==============================================================================
# Omnibus:                     8869.676   Durbin-Watson:                   2.006
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            34725.262
# Skew:                           1.776   Prob(JB):                         0.00
# Kurtosis:                       7.600   Cond. No.                         44.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#predictions for three point model

predictions = model.predict(X_test)
sns.set_context("paper", font_scale=1.5)
sns.set_style('white')
ax = sns.regplot(x = y_test, y = predictions,  scatter_kws={'alpha':0.05}, line_kws={"color": "red"})
sns.despine()
ax.set(xlim=(0, 20))
ax.set(ylim=(0, 10))
ax.set_title("Three Point Model")
plt.xlabel('True Defender Dist')
plt.ylabel('Predicted Defender Dist')
# Out:
# Text(0,0.5,'Predicted Defender Dist')
