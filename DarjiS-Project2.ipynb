# %%
from datascience import *

#importing things
import numpy as np

#setting up matplotlib to work inline
# %matplotlib inline
#importing pandas
import pandas as pd
#read in the housing data
df = pd.read_csv('NBA Franchise Record 2.csv')
sal = pd.read_csv('NBA_season1718_salary.csv')
pf = pd.read_csv('NBAPlayerSalary.csv')
df.head()
# Out:
#    Unnamed: 0          Franchise       Lg  From    To  Yrs     G     W     L  \
# 0           1      Atlanta Hawks      NBA  1950  2018   69  5470  2717  2753
# 1           2     Boston Celtics  NBA/BAA  1947  2018   72  5642  3329  2313
# 2           3      Brooklyn Nets  NBA/ABA  1968  2018   51  4140  1782  2358
# 3           4  Charlotte Hornets      NBA  1989  2018   28  2248   988  1260
# 4           5      Chicago Bulls      NBA  1967  2018   52  4215  2183  2032
#
#      PCT  Plyfs  Div  Conf  Champ
# 0  0.497     46   11     0      1
# 1  0.590     55   31     9     17
# 2  0.430     26    5     2      2
# 3  0.440     10    0     0      0
# 4  0.518     35    9     6      6

# %%
df = df.drop('Unnamed: 0', 1)

# %%
#tracing games win and loss ratio for teams 
columns = ['From','To','Lg']
nba = df.drop(columns, axis=1)
nba
# Out:
#                  Franchise  Yrs     G     W     L    PCT  Plyfs  Div  Conf  \
# 0            Atlanta Hawks   69  5470  2717  2753  0.497     46   11     0
# 1           Boston Celtics   72  5642  3329  2313  0.590     55   31     9
# 2            Brooklyn Nets   51  4140  1782  2358  0.430     26    5     2
# 3        Charlotte Hornets   28  2248   988  1260  0.440     10    0     0
# 4            Chicago Bulls   52  4215  2183  2032  0.518     35    9     6
# 5      Cleveland Cavaliers   48  3888  1829  2059  0.470     22    7     4
# 6         Dallas Mavericks   38  3068  1539  1529  0.502     21    3     2
# 7           Denver Nuggets   51  4140  2062  2078  0.498     33   10     0
# 8          Detroit Pistons   70  5532  2692  2840  0.487     41   11     5
# 9    Golden State Warriors   72  5638  2715  2923  0.482     34   11     4
# 10         Houston Rockets   51  4134  2172  1962  0.525     32    6     4
# ...

# %%
# %matplotlib inline
import seaborn as sns
sns.set(color_codes=True)
from scipy import stats
from scipy.stats import norm

# %%
#Plot the distribution for PCT
sns.distplot(pf["Salary"])
#Calculate the Kolmogorov–Smirnov statistic to test for normality
df_PCT = pf["Salary"]
stats.kstest(pf_PCT, 'norm', norm.fit(pf["Salary"]))
# Out:
# /Users/SonnyD/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-135-c3df1524578d> in <module>()
#       3 #Calculate the Kolmogorov–Smirnov statistic to test for normality
#       4 df_PCT = pf["Salary"]
# ----> 5 stats.kstest(pf_PCT, 'norm', norm.fit(pf["Salary"]))
#
# NameError: name 'pf_PCT' is not defined

# %%
sns.distplot(df["Yrs"])
# Out:
# /Users/SonnyD/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
# %matplotlib inline
import seaborn as sns
sns.set(color_codes=True)
from scipy import stats
from scipy.stats import norm
sal
# Out:
#      Unnamed: 0      Salary               Franchise       Lg    From      To  \
# 0             1  34682550.0           Atlanta Hawks      NBA  1950.0  2018.0
# 1             2  33285709.0          Boston Celtics  NBA/BAA  1947.0  2018.0
# 2             3  31269231.0           Brooklyn Nets  NBA/ABA  1968.0  2018.0
# 3             4  29727900.0       Charlotte Hornets      NBA  1989.0  2018.0
# 4             5  29512900.0           Chicago Bulls      NBA  1967.0  2018.0
# 5             6  28703704.0     Cleveland Cavaliers      NBA  1971.0  2018.0
# 6             7  28530608.0        Dallas Mavericks      NBA  1981.0  2018.0
# 7             8  28530608.0          Denver Nuggets  NBA/ABA  1968.0  2018.0
# 8             9  28299399.0         Detroit Pistons  NBA/BAA  1949.0  2018.0
# 9            10  27739975.0   Golden State Warriors  NBA/BAA  1947.0  2018.0
# 10           11  27734405.0         Houston Rockets      NBA  1968.0  2018.0
# ...

# %%
#Plot the Regression for PCT vs # of playoffs presented in NBA
sns.regplot(x=df["PCT"], y=df["Plyfs"])

# %%
#Plot the Regression for PCT vs # of division titles presented in NBA
sns.regplot(x=df["PCT"], y=df["Conf"])

# %%
pf =pf.rename(columns={'Unnamed: 0': 'Rank'})
pf
# Out:
#     Rank      Salary               Franchise       Lg    From      To   Yrs  \
# 0      1  34682550.0           Atlanta Hawks      NBA  1950.0  2018.0  69.0
# 1      2  33285709.0          Boston Celtics  NBA/BAA  1947.0  2018.0  72.0
# 2      3  31269231.0           Brooklyn Nets  NBA/ABA  1968.0  2018.0  51.0
# 3      4  29727900.0       Charlotte Hornets      NBA  1989.0  2018.0  28.0
# 4      5  29512900.0           Chicago Bulls      NBA  1967.0  2018.0  52.0
# 5      6  28703704.0     Cleveland Cavaliers      NBA  1971.0  2018.0  48.0
# 6      7  28530608.0        Dallas Mavericks      NBA  1981.0  2018.0  38.0
# 7      8  28530608.0          Denver Nuggets  NBA/ABA  1968.0  2018.0  51.0
# 8      9  28299399.0         Detroit Pistons  NBA/BAA  1949.0  2018.0  70.0
# 9     10  27739975.0   Golden State Warriors  NBA/BAA  1947.0  2018.0  72.0
# 10    11  27734405.0         Houston Rockets      NBA  1968.0  2018.0  51.0
# ...

# %%
#Plot the distribution for Price
sns.distplot(pf["Salary"])
#Calculate the Kolmogorov–Smirnov statistic to test for normality
df_salary = pf["Salary"]
stats.kstest(pf_salary, 'norm', norm.fit(pf["Salary"]))
# Out:
# /Users/SonnyD/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-248-5d7e07d7df1c> in <module>()
#       3 #Calculate the Kolmogorov–Smirnov statistic to test for normality
#       4 df_salary = pf["Salary"]
# ----> 5 stats.kstest(pf_salary, 'norm', norm.fit(pf["Salary"]))
#
# NameError: name 'pf_salary' is not defined

# %%
#Plot the Regression for Salary data for 2017-18 season vs # of playoff titles  for the NBA teams
g = sns.regplot(x=pf["Rank"], y=pf["Salary"])

# %%
import seaborn as sns
sns.loaddataset("NBA Franchise Record 2")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-234-ff10fe3fda2f> in <module>()
#       1 import seaborn as sns
# ----> 2 sns.loaddataset("NBA Franchise Record 2")
#
# AttributeError: module 'seaborn' has no attribute 'loaddataset'

# %%
import matplotlib.pyplot as plt

#Plot small multiples for PCT with Number of Championships
multiples = sns.FacetGrid(pf, col = "Champ")
multiples = multiples.map(plt.hist, "PCT")

# %%
import statsmodels.api as sm

X = df["PCT"]
Y = df["Plyfs"]

model = sm.OLS(Y,X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Plyfs   R-squared:                       0.869
# Model:                            OLS   Adj. R-squared:                  0.865
# Method:                 Least Squares   F-statistic:                     192.5
# Date:                Thu, 29 Nov 2018   Prob (F-statistic):           2.47e-14
# Time:                        22:14:09   Log-Likelihood:                -116.31
# No. Observations:                  30   AIC:                             234.6
# Df Residuals:                      29   BIC:                             236.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# PCT           60.4157      4.355     13.873      0.000      51.509      69.322
# ...

# %%
pf =pf.dropna()
pf.drop('Unnamed: 0', 1)
# Out:
#         Salary               Franchise       Lg    From      To   Yrs       G  \
# 0   34682550.0           Atlanta Hawks      NBA  1950.0  2018.0  69.0  5470.0
# 1   33285709.0          Boston Celtics  NBA/BAA  1947.0  2018.0  72.0  5642.0
# 2   31269231.0           Brooklyn Nets  NBA/ABA  1968.0  2018.0  51.0  4140.0
# 3   29727900.0       Charlotte Hornets      NBA  1989.0  2018.0  28.0  2248.0
# 4   29512900.0           Chicago Bulls      NBA  1967.0  2018.0  52.0  4215.0
# 5   28703704.0     Cleveland Cavaliers      NBA  1971.0  2018.0  48.0  3888.0
# 6   28530608.0        Dallas Mavericks      NBA  1981.0  2018.0  38.0  3068.0
# 7   28530608.0          Denver Nuggets  NBA/ABA  1968.0  2018.0  51.0  4140.0
# 8   28299399.0         Detroit Pistons  NBA/BAA  1949.0  2018.0  70.0  5532.0
# 9   27739975.0   Golden State Warriors  NBA/BAA  1947.0  2018.0  72.0  5638.0
# 10  27734405.0         Houston Rockets      NBA  1968.0  2018.0  51.0  4134.0
# ...

# %%
import statsmodels.api as sm

Y = pf["Salary"]
X = pf[["PCT", "Plyfs", "L", "W", "Yrs"]]

model = sm.OLS(Y,X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.985
# Model:                            OLS   Adj. R-squared:                  0.982
# Method:                 Least Squares   F-statistic:                     334.0
# Date:                Mon, 10 Dec 2018   Prob (F-statistic):           4.84e-22
# Time:                        10:48:43   Log-Likelihood:                -491.96
# No. Observations:                  30   AIC:                             993.9
# Df Residuals:                      25   BIC:                             1001.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# PCT         5.227e+07   5.52e+06      9.466      0.000    4.09e+07    6.36e+07
# ...

# %%
predictions = model.predict(X)
plt.figure(figsize = (20,10))
plt.scatter(predictions, Y)
plt.xlabel("Predicted Values from model")
plt.ylabel("Actual Value: Salaries")
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(X, model.fittedvalues, 'o')
plt.show()

# %%
#plots and fits the model on a least square regression fit
X = pf["Salary"]
Y = pf["W"]

m1 = sm.OLS(Y,X).fit()

fig, ax = plt.subplots(figsize=(15,10))
fig = sm.graphics.plot_fit(m1, 0, ax=ax)

# %%
predictions.head()
# Out:
# 0    2.715855e+07
# 1    2.919505e+07
# 2    2.822071e+07
# 3    2.498030e+07
# 4    2.758339e+07
# dtype: float64

# %%
# predicated salaries from model
pf["Salary"].head()
# Out:
# 0    34682550.0
# 1    33285709.0
# 2    31269231.0
# 3    29727900.0
# 4    29512900.0
# Name: Salary, dtype: float64

# %%
# Least Squares regression results
import statsmodels.api as sm

Y = pf["Salary"]
X = pf[["PCT", "Plyfs", "Champ", "W", "Yrs"]]

model = sm.OLS(Y,X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.988
# Model:                            OLS   Adj. R-squared:                  0.985
# Method:                 Least Squares   F-statistic:                     403.7
# Date:                Tue, 04 Dec 2018   Prob (F-statistic):           4.69e-23
# Time:                        18:07:27   Log-Likelihood:                -489.16
# No. Observations:                  30   AIC:                             988.3
# Df Residuals:                      25   BIC:                             995.3
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# PCT         5.458e+07   4.49e+06     12.158      0.000    4.53e+07    6.38e+07
# ...

# %%
#predications for the X variants that I have chosen from the columns given
print("Making predictions for the following 5 Teams:")
print(X.head())
# Out:
# Making predictions for the following 5 Teams:
#      PCT  Plyfs  Champ       W   Yrs
# 0  0.497   46.0    1.0  2717.0  69.0
# 1  0.590   55.0   17.0  3329.0  72.0
# 2  0.430   26.0    2.0  1782.0  51.0
# 3  0.440   10.0    0.0   988.0  28.0
# 4  0.518   35.0    6.0  2183.0  52.0

# %%
pf["Salary"][:5]
#X_test = X_test.reshape(-1, 1)
#Y_test = Y_test.reshape(-1,1)
#X_train = X_train.reshape(-1, 1)
#Y_train = Y_train.reshape(-1,1)
# Out:
# 0    34682550.0
# 1    33285709.0
# 2    31269231.0
# 3    29727900.0
# 4    29512900.0
# Name: Salary, dtype: float64

# %%
import sklearn.cross_validation

X_train, X_test, Y_train, Y_test = sklearn.cross_validation.train_test_split(X,Y, test_size=0.2, random_state=5)
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (24, 5)
# (24,)
# (6, 5)
# (6,)

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train, Y_train)

Y_pred = lm.predict(X_train)
Y_pred[:5]
# Out:
# array([29046353.89295086, 29183518.91842545, 24170305.22059824,
#        25015263.36531819, 23625177.2542346 ])

# %%
#From trained data: 80% split
print(sklearn.metrics.mean_squared_error(Y_train, lm.predict(X_train)))
# Out:
# 7865587396612.106

# %%
#From test data: 20% split
print(sklearn.metrics.mean_squared_error(Y_test, lm.predict(X_test)))
# Out:
# 10409287031201.11

# %%
plt.figure(figsize=(10,10))
plt.scatter(Y_train, Y_pred)
plt.xlabel("Salaries: $Y_i$")
plt.ylabel("Predicted Salaries: $\hat{Y}_i$")
plt.title("Prices vs Predicted Salaries: $Y_i$ vs $\hat{Y}_i$")
# Out:
# Text(0.5,1,'Prices vs Predicted Salaries: $Y_i$ vs $\\hat{Y}_i$')

# %%
print(lm.predict(X_test))
# Out:
# [26329527.33367533 27873488.03191996 23533782.30236639 28384965.28856923
#  24523644.30844173 25095560.92828564]

# %%
#2015-2016 nba salary dataset
nba2 = pd.read_csv('NBA2017-18Salary.csv')
nba = Table.read_table('NBA2017-18Salary.csv')
nba =nba.relabeled('Unnamed: 0', 'Rank')
nba = nba.relabeled('season17_18', 'Salary')

# %%
#shows mean,std, min,max, and percentile distribution for Salary and Rank
nba2 = nba2.rename(columns={'Unnamed: 0': 'Rank', 'season17_18' : 'Salary'})
nba2["Salary"] = pd.to_numeric(nba2["Salary"], downcast='float')
nba2.describe()
# Out:
#              Rank      Salary
# count  573.000000       573.0
# mean   287.000000   5858937.0
# std    165.555127   7162367.0
# min      1.000000     17224.0
# 25%    144.000000   1312611.0
# 50%    287.000000   2386864.0
# 75%    430.000000   7936509.0
# max    573.000000  34682552.0

# %%
nba2
# Out:
#      Rank               Player   Tm      Salary
# 0       1        Stephen Curry  GSW  34682552.0
# 1       2         LeBron James  CLE  33285708.0
# 2       3         Paul Millsap  DEN  31269232.0
# 3       4       Gordon Hayward  BOS  29727900.0
# 4       5        Blake Griffin  DET  29512900.0
# 5       6           Kyle Lowry  TOR  28703704.0
# 6       7    Russell Westbrook  OKC  28530608.0
# 7       8          Mike Conley  MEM  28530608.0
# 8       9         James Harden  HOU  28299400.0
# 9      10        DeMar DeRozan  TOR  27739976.0
# 10     11           Al Horford  BOS  27734404.0
# 11     12      Carmelo Anthony  OKC  26243760.0
# 12     13       Damian Lillard  POR  26153056.0
# 13     14         Jrue Holiday  NOP  25686668.0
# 14     15           Chris Bosh  MIA  25289390.0
# 15     16         Kevin Durant  GSW  25000000.0
# 16     17          Otto Porter  WAS  24773250.0
# 17     18           Chris Paul  HOU  24599496.0
# 18     19        C.J. McCollum  POR  23962572.0
# ...

# %%
#Sorts Team and Salary 
nba.sort('Tm','Salary')
# Out:
# Rank | Player           | Tm   | Salary
# 538  | Michael Young    | WAS  | 50000
# 537  | Daniel Ochefu    | WAS  | 50000
# 509  | Carrick Felix    | WAS  | 140902
# 498  | Ramon Sessions   | WAS  | 263124
# 459  | Martell Webster  | WAS  | 830000
# 386  | Chris McCullough | WAS  | 1.47138e+06
# 348  | Mike Scott       | WAS  | 1.70954e+06
# 331  | Tim Frazier      | WAS  | 2e+06
# 328  | Kelly Oubre      | WAS  | 2.09304e+06
# 260  | Tomas Satoransky | WAS  | 3e+06
# ... (563 rows omitted)

# %%
# Golden State Warrior Roster List
ps=nba.where('Tm',are.equal_to('GSW')).sort('Salary', descending=True)
ps
# Out:
# Rank | Player           | Tm   | Salary
# 1    | Stephen Curry    | GSW  | 3.46826e+07
# 16   | Kevin Durant     | GSW  | 2.5e+07
# 53   | Klay Thompson    | GSW  | 1.78262e+07
# 65   | Draymond Green   | GSW  | 1.64e+07
# 75   | Andre Iguodala   | GSW  | 1.48148e+07
# 146  | Shaun Livingston | GSW  | 7.69231e+06
# 197  | Nick Young       | GSW  | 5.192e+06
# 239  | Zaza Pachulia    | GSW  | 3.4776e+06
# 299  | David West       | GSW  | 2.32865e+06
# 321  | JaVale McGee     | GSW  | 2.11696e+06
# ... (6 rows omitted)

# %%
#scatter plot for Chicago Bulls sorted by rank
chi=nba.where('Tm', are.equal_to('CHI')).sort('Salary')
chi.scatter('Rank','Salary')

# %%
#drops position and player
tm = nba.drop('Player')

# %%
#Shows comparsion of rankVsalary between Chicago Bulls
#The Chicago Bulls for the 2017-2018 season had used the least amount cap space with $108,150,139 and data shows they paid less for salaries for thier players.
bn = tm.where('Tm', are.equal_to('CHI')).sort('Salary', descending=False)
bn.barh('Rank','Salary')
# 22 players ranked above 100
# 2 players ranked below 100

# %%
#Shows comparsion of rankVsalary between Cleveland Cavaliers
#The Cleveland Cavaliers for 2017-2018 season used the most total cap space for the season %135,980,450 and therefore were hard capped for the season
lk = tm.where('Tm', are.equal_to('CLE')).sort('Salary', descending=False)
lk.barh('Rank','Salary')
#only 5 players ranked below 100

# %%
#sorts Rank from lowest rank to highest
rankteam = tm.sort('Rank', descending = True)
rankteam
# Out:
# Rank | Tm   | Salary
# 573  | CHI  | 17224
# 572  | MIL  | 22248
# 571  | DET  | 25000
# 570  | HOU  | 25000
# 569  | NOP  | 25000
# 568  | NOP  | 25000
# 567  | ATL  | 26773
# 566  | CLE  | 46080
# 565  | DAL  | 46080
# 564  | IND  | 46080
# ... (563 rows omitted)

# %%
#how many players salary per team?
nb=nba.drop('Rank', 'Player')
teamcount = nb.group('Tm').barh('Tm','count')
#pl.barh('Player','Salary')
#pl.barh('Tm','Salary')

# %%
#2015 nba rookie salaries
pla =nba.where('Player', are.equal_to('Lonzo Ball')).sort('Salary', descending=True)
pla
# Out:
# Rank | Player     | Tm   | Salary
# 169  | Lonzo Ball | LAL  | 6.28656e+06
